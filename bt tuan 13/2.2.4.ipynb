# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#   AnimalName symptoms1             symptoms2 symptoms3    symptoms4  \
# 0        Dog     Fever              Diarrhea  Vomiting  Weight loss
# 1        Dog     Fever              Diarrhea  Coughing    Tiredness
# 2        Dog     Fever              Diarrhea  Coughing     Vomiting
# 3        Dog     Fever  Difficulty breathing  Coughing     Lethargy
# 4        Dog     Fever              Diarrhea  Coughing     Lethargy
#
#      symptoms5 Dangerous
# 0  Dehydration       Yes
# 1        Pains       Yes
# 2     Anorexia       Yes
# 3     Sneezing       Yes
# 4     Blue Eye       Yes

# %%
df.isnull().sum()
# Out:
# AnimalName    0
# symptoms1     0
# symptoms2     0
# symptoms3     0
# symptoms4     0
# symptoms5     0
# Dangerous     2
# dtype: int64

# %%
df = df.dropna(subset=['Dangerous'])

# %%
df['AnimalName'] = df['AnimalName'].fillna("Unknown")

# %%
X = df.drop("Dangerous", axis=1)
y = df["Dangerous"]

# One-hot encode AnimalName
X = pd.get_dummies(X, drop_first=True)

# Chuẩn hóa
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
from sklearn.svm import SVC

svm = SVC(kernel="rbf", C=1, gamma="scale")
svm.fit(X_train, y_train)

y_pred = svm.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9885057471264368
#               precision    recall  f1-score   support
#
#           No       0.00      0.00      0.00         2
#          Yes       0.99      1.00      0.99       172
#
#     accuracy                           0.99       174
#    macro avg       0.49      0.50      0.50       174
# weighted avg       0.98      0.99      0.98       174
# C:\Users\tnmt1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tnmt1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tnmt1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
params = {
    "C": [0.1, 1, 10, 100],
    "gamma": ["scale", 0.1, 0.01],
    "kernel": ["rbf"]
}

gs = GridSearchCV(SVC(), params, cv=4, scoring="accuracy")
gs.fit(X_train, y_train)

print("Best params:", gs.best_params_)
print("Best score:", gs.best_score_)
# Out:
# Best params: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Best score: 0.988489136934423
